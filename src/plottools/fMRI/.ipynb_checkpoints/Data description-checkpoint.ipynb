# %%
from pathlib import Path

import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

import ipywidgets as widgets

import h5py

# %matplotlib notebook
# Out:
# /home/marie/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# %matplotlib notebook
fig, sub = plt.subplots()

@widgets.interact(source=['IA3T', 'IOWA', 'MAGH', 'MINN', 'NMEX'])
def choose_source(source):
    source = Path('/media/marie/My Passport/DATASETS/MCIC')/source
    patients = sorted(source.iterdir())
    @widgets.interact(patient=patients)
    def choose_patient(patient):
        images_dir = patient/'month000'/'sm'
        
        @widgets.interact(imagefile=images_dir.iterdir())
        def choose_image(imagefile):
            imagefile = imagefile.iterdir().__next__()
            img = nib.load(str(imagefile))
            print(img.header)
            data = img.get_fdata()
            data -= data.min()
            data /= data.max()
            
            @widgets.interact(i=(0, data.shape[2]-1), t=(0, data.shape[3]-1), gamma=(0.5, 2))
            def replot(i, t, gamma):
                sub.clear()
                sub.imshow(data[:, :, i, t]**gamma, vmin=0, vmax=1, cmap='inferno')
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(Dropdown(description='source', options=('IA3T', 'IOWA', 'MAGH', 'MINN', 'NMEX'), value='…

# %%
with h5py.File('fALFFmap_IOWA.mat') as h5:
    print(h5['fALFF'])
    
    images = h5['fALFF'][...]
# Out:
# <HDF5 dataset "fALFF": shape (7, 63652, 14), type "<f8">

# %%
fig, sub = plt.subplots()

@widgets.interact(pat=(0, images.shape[0]-1), t=(0, images.shape[-1]-1))
def
# Out:
#   File "<ipython-input-4-82fef582deb5>", line 4
#     def
#         ^
# SyntaxError: invalid syntax
