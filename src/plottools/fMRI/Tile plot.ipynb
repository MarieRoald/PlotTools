# %%
import base
import h5py
from ipywidgets import interact
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

from tile_plots import create_fmri_timesteps_plot, create_fmri_factor_plot
# Out:
# /home/marie/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-f0d717cbfd3d> in <module>()
#       6 import numpy as np
#       7
# ----> 8 from tile_plots import create_fmri_timesteps_plot, create_fmri_factor_plot
#
# ~/Dropbox/Programming/Simula/PlotTools/plottools/fMRI/tile_plots.py in <module>()
#       2 import scipy.stats as st
#       3 import numpy as np
# ----> 4 from .base import tile_image, maryland_cmap
#       5
#       6
#
# ImportError: attempted relative import with no known parent package

# %%
filename = '/media/marie/My Passport/DATASETS/MCIC/fALFFmap_all.mat'
maskname = '/media/marie/My Passport/DATASETS/MCIC/mask.mat'

# %%
datafile = base.MatfileWrapper(filename, 'fALFF', filenames='fnames')
patient_data = datafile.load_all_patients()

# %%
print(patient_data.shape)
# Out:
# (260, 63652, 14)

# %%
mask = base.load_mask(maskname)
template = base.load_template()
num_slices = mask.shape[-1]

# %%
fmri_img = base.get_fMRI_images(patient_data[21], mask, axis=0)

# %%
type(fmri_img)
# Out:
# numpy.ma.core.MaskedArray

# %%
create_fmri_timesteps_plot(fmri_img, template, cmap=base.maryland_cmap, num_rows=4, num_cols=4, zscore=True)
# Out:
# (<Figure size 1152x1152 with 30 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f654a9bebe0>,
# ...
#        dtype=object))

# %%
create_fmri_factor_plot(fmri_img[...,0], template, cmap='RdBl', zscore=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-33329ae4a8b2> in <module>()
# ----> 1 create_fmri_factor_plot(fmri_img[...,0], template, cmap='RdBl', zscore=True)
#
# ~/Dropbox/Programming/Simula/PlotTools/fMRI/tile_plots.py in create_fmri_factor_plot(image, template, num_tile_rows, num_tile_cols, cmap, colorbar, zscore, rotation, figsize)
#      83         num_cols=num_tile_cols,
#      84         cmap=cmap,
# ---> 85         colorbar=colorbar
#      86     )
#      87
#
# ~/Dropbox/Programming/Simula/PlotTools/fMRI/tile_plots.py in create_tile_plot(image, template, ax, title, slice_idx, num_rows, num_cols, cmap, colorbar, rotation)
#     132         title=title,
#     133         cmap=cmap,
# --> 134         colorbar=colorbar,
#     135     )
#     136
#
# ...
